# %% [markdown]
# # Analyse de l'ampleur et du développement des violences sexuelles en France.

# %% [markdown]
# ## Pré-traitement des données pour Stata

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pour l'automatisation, on enregistre le chemin dans une varibale de manière à pouvoir changer le chemin facilement
path_to_file = './Données/tableaux-4001-ts.xlsx'

# %%
#importation des données
#feuille 1 : france_entière
df = pd.read_excel(path_to_file, sheet_name=0)
df.head(2)
# Out:
#    Index                                 libellé index  _2021_10  _2021_09  \
# 0      1        Règlements de compte entre malfaiteurs        16        12
# 1      2  Homicides pour voler et à l'occasion de vols         0         4
#
#    _2021_08  _2021_07  _2021_06  _2021_05  _2021_04  _2021_03  ...  _2000_10  \
# 0        15        11         8         6         4        13  ...         8
# 1         1         3         5         5         3         4  ...         3
#
#    _2000_09  _2000_08  _2000_07  _2000_06  _2000_05  _2000_04  _2000_03  \
# 0         8         6         5        12         5         2         9
# 1         4         9         5         4         4         7         6
#
#    _2000_02  _2000_01
# 0         5        11
# 1         5         2
#
# [2 rows x 264 columns]

# %%
#il faut résoudre le problème du double index
#pandas.DataFrame.set_index() définira la colonne passée en argument comme l’index de la DataFrame en surchargeant l’index initial.
#on utilise le libellé comme index
df.set_index('libellé index', inplace=True)
df.drop(columns = ['Index'], inplace = True)
df.head()
# Out:
#                                                     _2021_10  _2021_09  \
# libellé index
# Règlements de compte entre malfaiteurs                    16        12
# Homicides pour voler et à l'occasion de vols               0         4
# Homicides pour d'autres motifs                            72        68
# Tentatives d'homicides pour voler et à l'occasi...        11         6
# Tentatives homicides pour d'autres motifs                303       275
#
#                                                     _2021_08  _2021_07  \
# libellé index
# Règlements de compte entre malfaiteurs                    15        11
# Homicides pour voler et à l'occasion de vols               1         3
# Homicides pour d'autres motifs                            73        76
# Tentatives d'homicides pour voler et à l'occasi...        14        11
# Tentatives homicides pour d'autres motifs                301       267
#
#                                                     _2021_06  _2021_05  \
# libellé index
# Règlements de compte entre malfaiteurs                     8         6
# Homicides pour voler et à l'occasion de vols               5         5
# Homicides pour d'autres motifs                            89        84
# Tentatives d'homicides pour voler et à l'occasi...        14        14
# Tentatives homicides pour d'autres motifs                317       256
#
#                                                     _2021_04  _2021_03  \
# libellé index
# Règlements de compte entre malfaiteurs                     4        13
# Homicides pour voler et à l'occasion de vols               3         4
# Homicides pour d'autres motifs                            67        70
# Tentatives d'homicides pour voler et à l'occasi...        10         9
# Tentatives homicides pour d'autres motifs                243       241
#
#                                                     _2021_02  _2021_01  ...  \
# libellé index                                                           ...
# Règlements de compte entre malfaiteurs                     7         6  ...
# Homicides pour voler et à l'occasion de vols               1         0  ...
# Homicides pour d'autres motifs                            49        85  ...
# Tentatives d'homicides pour voler et à l'occasi...         8         6  ...
# Tentatives homicides pour d'autres motifs                258       236  ...
#
#                                                     _2000_10  _2000_09  \
# libellé index
# Règlements de compte entre malfaiteurs                     8         8
# Homicides pour voler et à l'occasion de vols               3         4
# Homicides pour d'autres motifs                            84        82
# Tentatives d'homicides pour voler et à l'occasi...        14         5
# Tentatives homicides pour d'autres motifs                 87        95
#
#                                                     _2000_08  _2000_07  \
# libellé index
# Règlements de compte entre malfaiteurs                     6         5
# Homicides pour voler et à l'occasion de vols               9         5
# Homicides pour d'autres motifs                            74        75
# Tentatives d'homicides pour voler et à l'occasi...         8        10
# Tentatives homicides pour d'autres motifs                 68       101
#
#                                                     _2000_06  _2000_05  \
# libellé index
# Règlements de compte entre malfaiteurs                    12         5
# Homicides pour voler et à l'occasion de vols               4         4
# Homicides pour d'autres motifs                            62        77
# Tentatives d'homicides pour voler et à l'occasi...        14        14
# Tentatives homicides pour d'autres motifs                 85       106
#
#                                                     _2000_04  _2000_03  \
# libellé index
# Règlements de compte entre malfaiteurs                     2         9
# Homicides pour voler et à l'occasion de vols               7         6
# Homicides pour d'autres motifs                            76        70
# Tentatives d'homicides pour voler et à l'occasi...         5         9
# Tentatives homicides pour d'autres motifs                 63       104
#
#                                                     _2000_02  _2000_01
# libellé index
# Règlements de compte entre malfaiteurs                     5        11
# Homicides pour voler et à l'occasion de vols               5         2
# Homicides pour d'autres motifs                            96        60
# Tentatives d'homicides pour voler et à l'occasi...        10         7
# Tentatives homicides pour d'autres motifs                 91        65
#
# [5 rows x 262 columns]

# %%
#on permute les lignes et colonnes
df_trans = df.transpose()
df_trans.head(3)
# Out:
# libellé index  Règlements de compte entre malfaiteurs  \
# _2021_10                                           16
# _2021_09                                           12
# _2021_08                                           15
#
# libellé index  Homicides pour voler et à l'occasion de vols  \
# _2021_10                                                  0
# _2021_09                                                  4
# _2021_08                                                  1
#
# libellé index  Homicides pour d'autres motifs  \
# _2021_10                                   72
# _2021_09                                   68
# _2021_08                                   73
#
# libellé index  Tentatives d'homicides pour voler et à l'occasion de vols  \
# _2021_10                                                      11
# _2021_09                                                       6
# _2021_08                                                      14
#
# libellé index  Tentatives homicides pour d'autres motifs  \
# _2021_10                                             303
# _2021_09                                             275
# _2021_08                                             301
#
# libellé index  Coups et blessures volontaires suivis de mort  \
# _2021_10                                                  13
# _2021_09                                                  18
# _2021_08                                                   6
#
# libellé index  Autres coups et blessures volontaires criminels ou correctionnels  \
# _2021_10                                                   28806
# _2021_09                                                   30662
# _2021_08                                                   27345
#
# libellé index  Prises d'otages à l'occasion de vols  \
# _2021_10                                          9
# _2021_09                                         11
# _2021_08                                          4
#
# libellé index  Prises d'otages dans un autre but  Sequestrations  ...  \
# _2021_10                                      12             464  ...
# _2021_09                                      11             449  ...
# _2021_08                                      17             385  ...
#
# libellé index  Banqueroutes, abus de biens sociaux et autres délits de société  \
# _2021_10                                                     117
# _2021_09                                                     120
# _2021_08                                                      70
#
# libellé index  Index non utilisé  Index non utilisé  \
# _2021_10                       0                  0
# _2021_09                       0                  0
# _2021_08                       0                  0
#
# libellé index  Prix illicittes, publicité fausse et infractions aux règles de la concurrence  \
# _2021_10                                                      86
# _2021_09                                                     105
# _2021_08                                                      80
#
# libellé index  Achats et ventes sans factures  \
# _2021_10                                   12
# _2021_09                                    5
# _2021_08                                    5
#
# libellé index  Infractions à l'exercice d'une profession règlementée  \
# _2021_10                                                     101
# _2021_09                                                      98
# _2021_08                                                      92
#
# libellé index  Infractions au droit de l'urbanisme et de la construction  \
# _2021_10                                                     477
# _2021_09                                                     455
# _2021_08                                                     363
#
# libellé index  Fraudes fiscales  Autres délits économiques et financiers  \
# _2021_10                     71                                     1759
# _2021_09                     71                                     1478
# _2021_08                     36                                     1334
#
# libellé index  Autres délits
# _2021_10               14520
# _2021_09               14657
# _2021_08               13162
#
# [3 rows x 107 columns]

# %%
#selectionner les colonnes avec les index correspondant aux infractions sexuelles (index 46 à 50)
df_sex = df_trans.iloc[:, 45:50]
df_sex.head()
# Out:
# libellé index  Viols sur des majeur(e)s  Viols sur des mineur(e)s  \
# _2021_10                           1595                      1650
# _2021_09                           1622                      1473
# _2021_08                           1400                      1257
# _2021_07                           1498                      1394
# _2021_06                           1615                      1789
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s  \
# _2021_10                                                    1574
# _2021_09                                                    1546
# _2021_08                                                    1349
# _2021_07                                                    1461
# _2021_06                                                    1590
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s  \
# _2021_10                                                    2523
# _2021_09                                                    2253
# _2021_08                                                    1675
# _2021_07                                                    1880
# _2021_06                                                    2564
#
# libellé index  Atteintes sexuelles
# _2021_10                      1360
# _2021_09                      1345
# _2021_08                      1184
# _2021_07                      1243
# _2021_06                      1451

# %%
#vérifier que les colonnes correspondent aux cinq infractions
print(list(df_sex.columns))
# Out:
# ['Viols sur des majeur(e)s', 'Viols sur des mineur(e)s', 'Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s', 'Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s', 'Atteintes sexuelles']

# %%
#ajout d'un index
df_sex.reset_index(inplace = True)
df_sex.head()
# Out:
# libellé index     index  Viols sur des majeur(e)s  Viols sur des mineur(e)s  \
# 0              _2021_10                      1595                      1650
# 1              _2021_09                      1622                      1473
# 2              _2021_08                      1400                      1257
# 3              _2021_07                      1498                      1394
# 4              _2021_06                      1615                      1789
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s  \
# 0                                                           1574
# 1                                                           1546
# 2                                                           1349
# 3                                                           1461
# 4                                                           1590
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s  \
# 0                                                           2523
# 1                                                           2253
# 2                                                           1675
# 3                                                           1880
# 4                                                           2564
#
# libellé index  Atteintes sexuelles
# 0                             1360
# 1                             1345
# 2                             1184
# 3                             1243
# 4                             1451

# %%
df_sex = df_sex.rename(columns = {'index':'Année_mois'})
df_sex.index.rename('Index', inplace=True)
df_sex.head()
# Out:
# libellé index Année_mois  Viols sur des majeur(e)s  Viols sur des mineur(e)s  \
# Index
# 0               _2021_10                      1595                      1650
# 1               _2021_09                      1622                      1473
# 2               _2021_08                      1400                      1257
# 3               _2021_07                      1498                      1394
# 4               _2021_06                      1615                      1789
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s  \
# Index
# 0                                                           1574
# 1                                                           1546
# 2                                                           1349
# 3                                                           1461
# 4                                                           1590
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s  \
# Index
# 0                                                           2523
# 1                                                           2253
# 2                                                           1675
# 3                                                           1880
# 4                                                           2564
#
# libellé index  Atteintes sexuelles
# Index
# 0                             1360
# 1                             1345
# 2                             1184
# 3                             1243
# 4                             1451

# %%
#supprimer le tiret bas devant la date
df_sex['Année_mois'] = df_sex['Année_mois'].str[1:]

# %%
#base de données contenant les infractions pour violences sexuelles entre 2000 et 2021
df_sex
# Out:
# libellé index Année_mois  Viols sur des majeur(e)s  Viols sur des mineur(e)s  \
# Index
# 0                2021_10                      1595                      1650
# 1                2021_09                      1622                      1473
# 2                2021_08                      1400                      1257
# 3                2021_07                      1498                      1394
# 4                2021_06                      1615                      1789
# ...                  ...                       ...                       ...
# 257              2000_05                       287                       513
# 258              2000_04                       231                       414
# 259              2000_03                       271                       513
# 260              2000_02                       254                       412
# 261              2000_01                       230                       353
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s  \
# Index
# 0                                                           1574
# 1                                                           1546
# 2                                                           1349
# 3                                                           1461
# 4                                                           1590
# ...                                                          ...
# 257                                                          407
# 258                                                          321
# 259                                                          402
# 260                                                          355
# 261                                                          411
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s  \
# Index
# 0                                                           2523
# 1                                                           2253
# 2                                                           1675
# 3                                                           1880
# 4                                                           2564
# ...                                                          ...
# 257                                                          904
# 258                                                          727
# 259                                                          766
# 260                                                          781
# 261                                                          666
#
# libellé index  Atteintes sexuelles
# Index
# 0                             1360
# 1                             1345
# 2                             1184
# 3                             1243
# 4                             1451
# ...                            ...
# 257                            997
# 258                            785
# 259                            874
# 260                            833
# 261                            728
#
# [262 rows x 6 columns]

# %%
#créer deux nouvelles colonnes pour l'année et le mois
df_sex['Année'] = df_sex['Année_mois'].str[:4]
df_sex['Mois'] = df_sex['Année_mois'].str[5:]
df_sex
# Out:
# libellé index Année_mois  Viols sur des majeur(e)s  Viols sur des mineur(e)s  \
# Index
# 0                2021_10                      1595                      1650
# 1                2021_09                      1622                      1473
# 2                2021_08                      1400                      1257
# 3                2021_07                      1498                      1394
# 4                2021_06                      1615                      1789
# ...                  ...                       ...                       ...
# 257              2000_05                       287                       513
# 258              2000_04                       231                       414
# 259              2000_03                       271                       513
# 260              2000_02                       254                       412
# 261              2000_01                       230                       353
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des majeur(e)s  \
# Index
# 0                                                           1574
# 1                                                           1546
# 2                                                           1349
# 3                                                           1461
# 4                                                           1590
# ...                                                          ...
# 257                                                          407
# 258                                                          321
# 259                                                          402
# 260                                                          355
# 261                                                          411
#
# libellé index  Harcèlements sexuels et autres agressions sexuelles contre des mineur(e)s  \
# Index
# 0                                                           2523
# 1                                                           2253
# 2                                                           1675
# 3                                                           1880
# 4                                                           2564
# ...                                                          ...
# 257                                                          904
# 258                                                          727
# 259                                                          766
# 260                                                          781
# 261                                                          666
#
# libellé index  Atteintes sexuelles Année Mois
# Index
# 0                             1360  2021   10
# 1                             1345  2021   09
# 2                             1184  2021   08
# 3                             1243  2021   07
# 4                             1451  2021   06
# ...                            ...   ...  ...
# 257                            997  2000   05
# 258                            785  2000   04
# 259                            874  2000   03
# 260                            833  2000   02
# 261                            728  2000   01
#
# [262 rows x 8 columns]

# %%
#exportation des données dans un fichier csv
df_sex.to_excel('./Données_générées/data_stata.xlsx')
